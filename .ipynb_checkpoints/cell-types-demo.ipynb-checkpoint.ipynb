# %% [markdown]
# # Understanding Code vs Markdown Cells

# %% [markdown]
# This notebook demonstrates the difference between Code cells and Markdown cells in Jupyter Notebook.
#
# Code cells are used for execution, while Markdown cells are used for explanation and documentation.

# %% [markdown]
# This notebook demonstrates the difference between Code cells and Markdown cells in Jupyter Notebook.
#
# Code cells are used for execution, while Markdown cells are used for explanation and documentation.

# %%
print("This is a code cell execution")
# Out:
# This is a code cell execution

# %% [markdown]
# The above output shows that Code cells execute Python statements and display results.

# %% [markdown]
# ## Example: Simple Calculation
#
# The next cell performs a basic calculation.

# %% [markdown]
# ## Example: Simple Calculation
#
# The next cell performs a basic calculation.

# %%
a = 10
b = 5
print("Sum:", a + b)
# Out:
# Sum: 15

# %% [markdown]
# The code above defines two variables and prints their sum.
# This demonstrates how Code cells are used to perform computations.

# %%
x = 10
print("x =", x)
# Out:
# x = 10

# %%
print("x + 5 =", x + 5)
# Out:
# x + 5 = 15

# %%
print(x)
# Out:
# 10

# %%
while True:
    pass
