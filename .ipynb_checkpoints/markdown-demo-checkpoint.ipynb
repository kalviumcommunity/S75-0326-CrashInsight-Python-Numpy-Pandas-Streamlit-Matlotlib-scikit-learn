# %% [markdown]
# markdown-demo

# %% [markdown]
# This notebook demonstrates how to use Markdown for headings, lists, and code blocks.
#
# Markdown helps explain the logic behind code and makes notebooks easier to understand.

# %% [markdown]
# ## 1. Headings Example
#
# ### Subheading Example
#
# Markdown supports different heading levels to structure content clearly.

# %% [markdown]
# ## 2. Lists Example
#
# ### Unordered List
#
# - Step 1: Load data
# - Step 2: Clean data
# - Step 3: Analyze data
#
# ### Ordered List
#
# 1. Define variables
# 2. Perform calculation
# 3. Display output

# %% [markdown]
# ## 3. Inline Code Example
#
# We can use `print()` to display output.
#
# Variables like `x` and `y` can be referenced inline.

# %% [markdown]
# ## 4. Code Block Example
#
# ```python
# x = 10
# y = 20
# print(x + y)

# %% [markdown]
# (Yes, nested triple backticks—don’t mess this up)
#
# ---
#
# # Step 7 — Combine Markdown + Code (Correct Pattern)
#
# ## Cell 7 — Markdown
#
# ```markdown
# ## 5. Combining Markdown and Code
#
# The following code calculates the sum of two numbers.

# %%
x = 10
y = 5
print("Sum:", x + y)
# Out:
# Sum: 15

# %% [markdown]
# The output shows the sum of two variables, demonstrating how code execution works.
