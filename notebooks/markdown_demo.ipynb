# %% [markdown]
# # Writing Markdown for Headings, Lists, and Code Blocks in Notebooks
#
# This notebook demonstrates basic markdown syntax used in Jupyter notebooks.
#
# ## Headings
#
# Headings are created using # symbols.
#
# ### Level 3 Heading
#
# #### Level 4 Heading
#
# ##### Level 5 Heading
#
# ###### Level 6 Heading

# %% [markdown]
# ## Lists
#
# ### Unordered Lists
#
# - Item 1
# - Item 2
#   - Subitem 2.1
#   - Subitem 2.2
# - Item 3
#
# ### Ordered Lists
#
# 1. First item
# 2. Second item
#    1. Subitem 2.1
#    2. Subitem 2.2
# 3. Third item

# %% [markdown]
# ## Code Blocks
#
# Code blocks are enclosed in triple backticks.
#
# ```
# print("Hello, World!")
# ```
#
# You can specify the language:
#
# ```python
# def hello():
#     print("Hello from Python!")
# ```
#
# ```javascript
# console.log("Hello from JS!");
# ```

# %% [markdown]
# ### More Examples of Headings
#
# # Main Title
#
# ## Section 1
#
# ### Subsection 1.1
#
# ## Section 2
#
# ### Subsection 2.1
#
# #### Subsubsection 2.1.1

# %% [markdown]
# ### More Examples of Lists
#
# - Fruits:
#   - Apple
#   - Banana
#   - Cherry
#
# - Vegetables:
#   - Carrot
#   - Broccoli
#   - Spinach
#
# 1. Step one
# 2. Step two
# 3. Step three
# 4. Step four

# %% [markdown]
# ### More Code Blocks
#
# ```bash
# echo "Hello from Bash!"
# ```
#
# ```sql
# SELECT * FROM users;
# ```
#
# ```html
# <h1>Hello HTML</h1>
# ```
#
# ```css
# body { color: blue; }
# ```

# %% [markdown]
# ## Combining Elements
#
# ### A List with Code
#
# - Example 1:
#   ```python
#   x = 5
#   print(x)
#   ```
#
# - Example 2:
#   ```python
#   y = 10
#   print(y * 2)
#   ```

# %% [markdown]
# ### Headings in Lists
#
# - # Heading in List
# - ## Another Heading
# - Normal item

# %% [markdown]
# ## Summary
#
# Markdown allows you to format text in notebooks:
#
# - Use # for headings
# - Use - or numbers for lists
# - Use ``` for code blocks
#
# This makes notebooks more readable and organized.

# %%
# This is a code cell
# You can run Python code here
print("Markdown demo complete!")
